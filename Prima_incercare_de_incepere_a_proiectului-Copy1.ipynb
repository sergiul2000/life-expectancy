# %%
import pandas as pd

# %%
pd.DataFrame({'yes': ['ba nu!','esti gras!'], 'no': ['asa!','asa!']},index=['Merg la fotbal in loc sa merg cu lari la cumparaturi?','ar merge o pizza...'])
# Out:
#                                                            yes    no
# Merg la fotbal in loc sa merg cu lari la cumpar...      ba nu!  asa!
# ar merge o pizza...                                 esti gras!  asa!

# %%
pd.Series([1, 2, 3, 4, 5],index=[4,2,5,6,8])
# Out:
# 4    1
# 2    2
# 5    3
# 6    4
# 8    5
# dtype: int64

# %%
df=pd.read_csv("D:/Workshop_python/Proiect_life_expectation/Life_Expectancy_DATA_v1.csv")
df_stats=df.loc[:,df.columns!='Year'].groupby('Country', as_index = False).mean()
df_stats
# Out:
#                                 Country  Life expectancy   \
# 0                           Afghanistan          58.19375
# 1                               Albania          75.15625
# 2                               Algeria          73.61875
# 3                                Angola          49.01875
# 4                   Antigua and Barbuda          75.05625
# ..                                  ...               ...
# 188  Venezuela (Bolivarian Republic of)          73.38750
# 189                            Viet Nam          74.77500
# 190                               Yemen          63.86250
# 191                              Zambia          53.90625
# 192                            Zimbabwe          50.48750
#
#      Adult Mortality per 1000  infant deaths per 1000  Alcohol per capita  \
# 0                    269.0625                 78.2500            0.014375
# 1                     45.0625                  0.6875            4.848750
# ...

# %%
df.head(9)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality per 1000  \
# 0  Afghanistan  2015  Developing              65.0                     263.0
# 1  Afghanistan  2014  Developing              59.9                     271.0
# 2  Afghanistan  2013  Developing              59.9                     268.0
# 3  Afghanistan  2012  Developing              59.5                     272.0
# 4  Afghanistan  2011  Developing              59.2                     275.0
# 5  Afghanistan  2010  Developing              58.8                     279.0
# 6  Afghanistan  2009  Developing              58.6                     281.0
# 7  Afghanistan  2008  Developing              58.1                     287.0
# 8  Afghanistan  2007  Developing              57.5                     295.0
#
#    infant deaths per 1000  Alcohol per capita  \
# 0                      62                0.01
# 1                      64                0.01
# 2                      66                0.01
# ...

# %%
df.groupby('Country', as_index = False).mean()
# Out:
#                                 Country    Year  Life expectancy   \
# 0                           Afghanistan  2007.5          58.19375
# 1                               Albania  2007.5          75.15625
# 2                               Algeria  2007.5          73.61875
# 3                                Angola  2007.5          49.01875
# 4                   Antigua and Barbuda  2007.5          75.05625
# ..                                  ...     ...               ...
# 188  Venezuela (Bolivarian Republic of)  2007.5          73.38750
# 189                            Viet Nam  2007.5          74.77500
# 190                               Yemen  2007.5          63.86250
# 191                              Zambia  2007.5          53.90625
# 192                            Zimbabwe  2007.5          50.48750
#
#      Adult Mortality per 1000  infant deaths per 1000  Alcohol per capita  \
# 0                    269.0625                 78.2500            0.014375
# ...

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.heatmap(df.corr())
